# %%
pip install tensorflow matplot streamlit numpy pandas manim
# Out:
# Requirement already satisfied: tensorflow in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (2.15.0)
# Requirement already satisfied: matplot in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (0.1.9)
# Requirement already satisfied: streamlit in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (1.33.0)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (1.24.4)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (2.1.1)
# Requirement already satisfied: manim in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (0.18.0)
# Requirement already satisfied: tensorflow-macos==2.15.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow) (21.3)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow) (4.23.4)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow) (63.2.0)
# Requirement already satisfied: six>=1.12.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow) (4.11.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow) (1.60.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow) (2.15.1)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorflow-macos==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: pyloco>=0.0.134 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplot) (0.0.139)
# Requirement already satisfied: matplotlib>=3.1.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplot) (3.5.3)
# Requirement already satisfied: altair<6,>=4.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from streamlit) (5.3.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from streamlit) (1.7.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from streamlit) (5.3.2)
# Requirement already satisfied: click<9,>=7.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from streamlit) (8.1.3)
# Requirement already satisfied: pillow<11,>=7.1.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from streamlit) (9.2.0)
# Requirement already satisfied: pyarrow>=7.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from streamlit) (15.0.2)
# Requirement already satisfied: requests<3,>=2.27 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from streamlit) (2.28.1)
# Requirement already satisfied: rich<14,>=10.14.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from streamlit) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from streamlit) (8.2.3)
# Requirement already satisfied: toml<2,>=0.10.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from streamlit) (0.8.1b0)
# Requirement already satisfied: tornado<7,>=6.0.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from streamlit) (6.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas) (2022.2.1)
# Requirement already satisfied: tzdata>=2022.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: Pygments<3.0.0,>=2.10.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from manim) (2.13.0)
# Requirement already satisfied: click-default-group<2.0.0,>=1.2.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from manim) (1.2.4)
# Requirement already satisfied: cloup<2.2,>=0.13 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from manim) (2.1.2)
# Requirement already satisfied: decorator<6.0.0,>=5.0.7 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from manim) (5.1.1)
# Requirement already satisfied: isosurfaces==0.1.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from manim) (0.1.0)
# Requirement already satisfied: manimpango<1.0.0,>=0.5.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from manim) (0.5.0)
# Requirement already satisfied: mapbox-earcut<2.0.0,>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from manim) (1.0.1)
# Requirement already satisfied: moderngl<6.0.0,>=5.6.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from manim) (5.10.0)
# Requirement already satisfied: moderngl-window<3.0.0,>=2.3.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from manim) (2.4.4)
# Requirement already satisfied: networkx<3.3,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from manim) (2.8.8)
# Requirement already satisfied: pycairo<2.0,>=1.21 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from manim) (1.26.0)
# Requirement already satisfied: pydub<0.26.0,>=0.25.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from manim) (0.25.1)
# Requirement already satisfied: scipy<2.0.0,>=1.7.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from manim) (1.9.0)
# Requirement already satisfied: screeninfo<0.9,>=0.8 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from manim) (0.8.1)
# Requirement already satisfied: skia-pathops<0.8.0,>=0.7.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from manim) (0.7.4)
# Requirement already satisfied: srt<4.0.0,>=3.5.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from manim) (3.5.3)
# Requirement already satisfied: svgelements<2.0.0,>=1.8.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from manim) (1.9.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.62.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from manim) (4.66.2)
# Requirement already satisfied: watchdog<=3.0.0,>=2.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from manim) (3.0.0)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit) (4.14.0)
# Requirement already satisfied: toolz in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=3.1.1->matplot) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=3.1.1->matplot) (4.37.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=3.1.1->matplot) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=3.1.1->matplot) (3.0.9)
# Requirement already satisfied: glcontext<3,>=2.5.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from moderngl<6.0.0,>=5.6.3->manim) (2.5.0)
# Requirement already satisfied: pyglet>=2.0dev23 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from moderngl-window<3.0.0,>=2.3.0->manim) (2.1.dev1)
# Requirement already satisfied: pyrr<1,>=0.10.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from moderngl-window<3.0.0,>=2.3.0->manim) (0.10.3)
# Requirement already satisfied: ushlex in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyloco>=0.0.134->matplot) (0.99.1)
# Requirement already satisfied: websocket-client in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyloco>=0.0.134->matplot) (1.7.0)
# Requirement already satisfied: twine in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyloco>=0.0.134->matplot) (5.0.0)
# Requirement already satisfied: typing in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyloco>=0.0.134->matplot) (3.7.4.3)
# Requirement already satisfied: SimpleWebSocketServer in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyloco>=0.0.134->matplot) (0.1.2)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests<3,>=2.27->streamlit) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests<3,>=2.27->streamlit) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests<3,>=2.27->streamlit) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests<3,>=2.27->streamlit) (2022.9.24)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: Cython in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from screeninfo<0.9,>=0.8->manim) (3.0.10)
# Requirement already satisfied: pyobjc-framework-Cocoa in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from screeninfo<0.9,>=0.8->manim) (10.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow-macos==2.15.0->tensorflow) (0.42.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.1)
# Requirement already satisfied: attrs>=17.4.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.1)
# Requirement already satisfied: mdurl~=0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: multipledispatch in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyrr<1,>=0.10.3->moderngl-window<3.0.0,>=2.3.0->manim) (0.6.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (3.5.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (2.2.2)
# Requirement already satisfied: pyobjc-core>=10.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyobjc-framework-Cocoa->screeninfo<0.9,>=0.8->manim) (10.2)
# Requirement already satisfied: pkginfo>=1.8.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from twine->pyloco>=0.0.134->matplot) (1.10.0)
# Requirement already satisfied: readme-renderer>=35.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from twine->pyloco>=0.0.134->matplot) (43.0)
# Requirement already satisfied: requests-toolbelt!=0.9.0,>=0.8.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from twine->pyloco>=0.0.134->matplot) (1.0.0)
# Requirement already satisfied: importlib-metadata>=3.6 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from twine->pyloco>=0.0.134->matplot) (7.1.0)
# Requirement already satisfied: keyring>=15.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from twine->pyloco>=0.0.134->matplot) (25.1.0)
# Requirement already satisfied: rfc3986>=1.4.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from twine->pyloco>=0.0.134->matplot) (2.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from importlib-metadata>=3.6->twine->pyloco>=0.0.134->matplot) (3.18.1)
# Requirement already satisfied: jaraco.classes in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from keyring>=15.1->twine->pyloco>=0.0.134->matplot) (3.4.0)
# Requirement already satisfied: jaraco.functools in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from keyring>=15.1->twine->pyloco>=0.0.134->matplot) (4.0.0)
# Requirement already satisfied: jaraco.context in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from keyring>=15.1->twine->pyloco>=0.0.134->matplot) (5.3.0)
# Requirement already satisfied: nh3>=0.2.14 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot) (0.2.17)
# Requirement already satisfied: docutils>=0.13.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot) (0.20.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-macos==2.15.0->tensorflow) (3.2.2)
# Requirement already satisfied: more-itertools in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from jaraco.classes->keyring>=15.1->twine->pyloco>=0.0.134->matplot) (10.2.0)
# Requirement already satisfied: backports.tarfile in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from jaraco.context->keyring>=15.1->twine->pyloco>=0.0.134->matplot) (1.0.0)
# WARNING: There was an error checking the latest version of pip.
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import tensorflow as tf 
from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# imported all the neccessary libraries here

# %%
data_train_path="dataset/train"
data_test_path="dataset/test"
data_val_path="dataset/validation"

# %% [markdown]
# set the path of each train , test and validate folder

# %%
img_width=180
img_height=180

# %% [markdown]
# scaled the images to 180x180 to make it uniform

# %%
data_train=tf.keras.utils.image_dataset_from_directory(
    data_train_path,
    shuffle=True,
    image_size=(img_width,img_height),
    batch_size=32,
    validation_split=False)
# Out:
# Found 449 files belonging to 5 classes.

# %% [markdown]
# validation set is false coz we dont have to split our dataset we already have a validation set

# %%
data_cat=data_train.class_names

# %%
data_cat
# Out:
# ['barbell', 'dumbell', 'gym_ball', 'kettlebell', 'smith_machine']

# %%
data_val=tf.keras.utils.image_dataset_from_directory(
    data_val_path,
    shuffle=False,
    image_size=(img_width,img_height),
    batch_size=32,
    validation_split=False)
# Out:
# Found 50 files belonging to 5 classes.

# %%
data_test=tf.keras.utils.image_dataset_from_directory(
    data_test_path,
    shuffle=True,
    image_size=(img_width,img_height),
    batch_size=32,
    validation_split=False)
# Out:
# Found 48 files belonging to 5 classes.

# %%
plt.figure(figsize=(10,10))
for image, labels in data_train.take(1):
    for i in range(9):
        plt.subplot(3,3,i+1)
        plt.imshow(image[i].numpy().astype('uint8'))
        plt.title(data_cat[labels[i]])
        plt.axis('off')

# %% [markdown]
# So here we see the images whicha are there

# %%
from tensorflow.keras.models import Sequential

# %%
data_train
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %% [markdown]
# 180x180 is height of photo and 3 is for rgb

# %%
model = Sequential([
    layers.Rescaling(1./255),
    layers.Conv2D(16, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32,3, padding='same',activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dropout(0.2),
    layers.Dense(128),
    layers.Dense(len(data_cat))
                  
])

# %%
model.compile(optimizer='adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

# %%
epochs_size = 25
history = model.fit(data_train, validation_data=data_val, epochs=epochs_size)
# Out:
# Epoch 1/25
# 15/15 [==============================] - 3s 133ms/step - loss: 3.4403 - accuracy: 0.2873 - val_loss: 1.4713 - val_accuracy: 0.4600
# Epoch 2/25
# 15/15 [==============================] - 3s 129ms/step - loss: 1.1755 - accuracy: 0.6615 - val_loss: 2.3966 - val_accuracy: 0.2400
# Epoch 3/25
# 15/15 [==============================] - 3s 130ms/step - loss: 0.8518 - accuracy: 0.6993 - val_loss: 0.9793 - val_accuracy: 0.6600
# Epoch 4/25
# 15/15 [==============================] - 3s 132ms/step - loss: 0.4568 - accuracy: 0.8508 - val_loss: 0.9794 - val_accuracy: 0.6800
# Epoch 5/25
# 15/15 [==============================] - 3s 130ms/step - loss: 0.2448 - accuracy: 0.9087 - val_loss: 0.9656 - val_accuracy: 0.6800
# Epoch 6/25
# 15/15 [==============================] - 3s 132ms/step - loss: 0.1498 - accuracy: 0.9555 - val_loss: 1.1130 - val_accuracy: 0.7000
# Epoch 7/25
# 15/15 [==============================] - 3s 135ms/step - loss: 0.0969 - accuracy: 0.9599 - val_loss: 1.2325 - val_accuracy: 0.7200
# Epoch 8/25
# 15/15 [==============================] - 3s 137ms/step - loss: 0.0661 - accuracy: 0.9822 - val_loss: 1.7772 - val_accuracy: 0.6600
# Epoch 9/25
# 15/15 [==============================] - 3s 133ms/step - loss: 0.0523 - accuracy: 0.9889 - val_loss: 1.2406 - val_accuracy: 0.7000
# Epoch 10/25
# 15/15 [==============================] - 3s 134ms/step - loss: 0.0856 - accuracy: 0.9666 - val_loss: 1.5386 - val_accuracy: 0.6400
# Epoch 11/25
# 15/15 [==============================] - 3s 137ms/step - loss: 0.0485 - accuracy: 0.9889 - val_loss: 2.3182 - val_accuracy: 0.6000
# Epoch 12/25
# 15/15 [==============================] - 3s 135ms/step - loss: 0.0473 - accuracy: 0.9866 - val_loss: 1.2242 - val_accuracy: 0.7000
# Epoch 13/25
# 15/15 [==============================] - 3s 137ms/step - loss: 0.0385 - accuracy: 0.9911 - val_loss: 1.3449 - val_accuracy: 0.7200
# Epoch 14/25
# 15/15 [==============================] - 3s 140ms/step - loss: 0.0423 - accuracy: 0.9889 - val_loss: 1.2085 - val_accuracy: 0.6800
# Epoch 15/25
# 15/15 [==============================] - 3s 139ms/step - loss: 0.0279 - accuracy: 0.9933 - val_loss: 1.1935 - val_accuracy: 0.7200
# Epoch 16/25
# 15/15 [==============================] - 3s 140ms/step - loss: 0.0250 - accuracy: 0.9955 - val_loss: 1.4322 - val_accuracy: 0.7200
# Epoch 17/25
# 15/15 [==============================] - 3s 139ms/step - loss: 0.0198 - accuracy: 0.9955 - val_loss: 1.2669 - val_accuracy: 0.7000
# Epoch 18/25
# 15/15 [==============================] - 3s 142ms/step - loss: 0.0212 - accuracy: 0.9955 - val_loss: 1.4538 - val_accuracy: 0.7000
# Epoch 19/25
# 15/15 [==============================] - 3s 142ms/step - loss: 0.0575 - accuracy: 0.9911 - val_loss: 1.5323 - val_accuracy: 0.6800
# Epoch 20/25
# 15/15 [==============================] - 3s 144ms/step - loss: 0.0260 - accuracy: 0.9955 - val_loss: 1.4741 - val_accuracy: 0.6600
# Epoch 21/25
# 15/15 [==============================] - 3s 157ms/step - loss: 0.0161 - accuracy: 0.9933 - val_loss: 1.6446 - val_accuracy: 0.6600
# Epoch 22/25
# 15/15 [==============================] - 3s 150ms/step - loss: 0.0304 - accuracy: 0.9933 - val_loss: 1.2730 - val_accuracy: 0.7200
# Epoch 23/25
# 15/15 [==============================] - 3s 153ms/step - loss: 0.0229 - accuracy: 0.9955 - val_loss: 1.2391 - val_accuracy: 0.7400
# Epoch 24/25
# 15/15 [==============================] - 4s 161ms/step - loss: 0.0142 - accuracy: 0.9955 - val_loss: 1.5156 - val_accuracy: 0.7200
# Epoch 25/25
# 15/15 [==============================] - 4s 166ms/step - loss: 0.0386 - accuracy: 0.9933 - val_loss: 1.4119 - val_accuracy: 0.7000

# %% [markdown]
# 98 is number of batches

# %%
fig, axs = plt.subplots(1, 2, figsize=(8, 8))

axs[0].plot(epochs_range, history.history['accuracy'], label='Training Accuracy')
axs[0].plot(epochs_range, history.history['val_accuracy'], label='Validation Accuracy')
axs[0].set_title('Accuracy')

axs[1].plot(epochs_range, history.history['loss'], label='Training Loss')
axs[1].plot(epochs_range, history.history['val_loss'], label='Validation Loss')
axs[1].set_title('Loss')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [16], in <cell line: 3>()
#       1 fig, axs = plt.subplots(1, 2, figsize=(8, 8))
# ----> 3 axs[0].plot(epochs_range, history.history['accuracy'], label='Training Accuracy')
#       4 axs[0].plot(epochs_range, history.history['val_accuracy'], label='Validation Accuracy')
#       5 axs[0].set_title('Accuracy')
#
# NameError: name 'epochs_range' is not defined

# %%
import tensorflow as tf

# Assuming img_height and img_width are defined somewhere in your code
img_height, img_width = 180, 180  # Example values, adjust as needed

# Load the image file
user_upload = "dataset/user_upload/img2.jpg"
image = tf.keras.utils.load_img(user_upload, target_size=(img_height, img_width))

# Convert the PIL Image to a NumPy array
img_arr = tf.keras.preprocessing.image.img_to_array(image)

# Expand dimensions to add the batch size as the first dimension
img_bat = tf.expand_dims(img_arr, 0)

# %%
predict=model.predict(img_bat)
# Out:
# 1/1 [==============================] - 0s 53ms/step

# %%
score=tf.nn.softmax(predict)

# %%
print('The object  in the  image is {} with accuracy of {:0.2f}%'.format(data_cat[np.argmax(score)],np.max(score)*100))
# Out:
# The object  in the  image is smith_machine with accuracy of 100.00%

# %%
model.save('imageclassification.keras')

# %%
from typing import Dict

# Dictionary mapping machines to their suggested exercises for each body part
machine_exercises = {
    'barbell': {
        'upper_body': ['Bench Press', 'Barbell Rows', 'Overhead Press'],
        'lower_body': ['Squats', 'Deadlifts', 'Lunges'],
        'core': ['Russian Twists', 'Barbell Rollouts', 'Hanging Leg Raises']
    },
    'dumbbell': {
        'upper_body': ['Dumbbell Chest Press', 'Shoulder Press', 'Dumbbell Rows'],
        'lower_body': ['Dumbbell Squats', 'Dumbbell Romanian Deadlifts', 'Step-ups'],
        'core': ['Dumbbell Side Bends', 'Dumbbell Woodchoppers', 'Plank Rows']
    },
    'gym_ball': {
        'core': ['Ball Crunches', 'Plank with Leg Lifts', 'Russian Twists']
    },
    'kettlebell': {
        'upper_body': ['Kettlebell Swings', 'Kettlebell Press', 'Kettlebell Rows'],
        'lower_body': ['Kettlebell Goblet Squats', 'Kettlebell Lunges', 'Kettlebell Deadlifts'],
        'core': ['Kettlebell Russian Twists', 'Kettlebell Windmills', 'Kettlebell Turkish Get-ups']
    },
    'smith_machine': {
        'upper_body': ['Smith Machine Bench Press', 'Smith Machine Shoulder Press', 'Smith Machine Rows'],
        'lower_body': ['Smith Machine Squats', 'Smith Machine Lunges', 'Smith Machine Deadlifts']
    }
}

# Dictionary to map exercise names to their corresponding links
exercise_links = {
    'Bench Press': 'https://www.youtube.com/shorts/0cXAp6WhSj4',
    'Barbell Rows': 'https://www.youtube.com/shorts/Nqh7q3zDCoQ',
    'Overhead Press': 'https://www.youtube.com/shorts/zSU7T1zZagQ',
    'Squats': 'https://www.youtube.com/shorts/gslEzVggur8',
    'Deadlifts': 'https://www.youtube.com/shorts/8np3vKDBJfc',
    'Lunges': 'https://www.youtube.com/shorts/TwEH620Pn6A',
    'Russian Twists': 'https://www.youtube.com/watch?v=Tau0hsW8iR0',
    'Barbell Rollouts': 'https://www.youtube.com/watch?v=3C1TRMJveXo',
    'Hanging Leg Raises': 'https://www.youtube.com/shorts/2n4UqRIJyk4',
    'Dumbbell Chest Press': 'https://www.youtube.com/shorts/SidmT09GXz8',
    'Shoulder Press': 'https://www.youtube.com/shorts/dyv6g4xBFGU',
    'Dumbbell Rows': 'https://www.youtube.com/shorts/s1H87k4tAaA',
    'Dumbbell Squats': 'https://www.youtube.com/shorts/eLX_dyvooKQ',
    'Dumbbell Romanian Deadlifts': 'https://www.youtube.com/shorts/u14AwrUcwWw',
    'Step-ups': 'https://www.youtube.com/shorts/PzDbmqL6qo8Dumbbell',
    'Dumbbell Side Bends': 'https://www.youtube.com/watch?v=dL9ZzqtQI5c', 
    'Dumbbell Woodchoppers': 'https://www.youtube.com/shorts/OgQU_bbdB7c',
    'Plank Rows': 'https://www.youtube.com/watch?v=Gtc_Ns3qYYo',
    'Ball Crunches': 'https://www.youtube.com/watch?v=O4d3kd1ZLyc',
    'Plank with Leg Lifts': 'https://www.youtube.com/shorts/s_8PheAKUYk',
    'Kettlebell Swings': 'https://www.youtube.com/shorts/SR_4kUbkEaw',
    'Kettlebell Press': 'https://www.youtube.com/watch?v=eKQ0JOx_1qI',
    'Kettlebell Rows': 'https://www.youtube.com/shorts/e4OSLk1qZOQ',
    'Kettlebell Goblet Squats': 'https://www.youtube.com/shorts/dBnNCOtuGNQ',
    'Kettlebell Lunges': 'https://www.youtube.com/shorts/otd2YQk7osI',
    'Kettlebell Deadlifts': 'https://www.youtube.com/shorts/I7q_EPywprs',
    'Kettlebell Russian Twists': 'https://www.youtube.com/shorts/BA-uP_-bVE8',
    'Kettlebell Windmills': 'https://www.youtube.com/shorts/OVNXkKsfy7o',
    'Kettlebell Turkish Get-ups': 'https://www.youtube.com/shorts/-dfk79o6iHI',
    'Smith Machine Bench Press': 'https://www.youtube.com/shorts/G-jT0m0nvx8',
    'Smith Machine Shoulder Press': 'https://www.youtube.com/shorts/QWdaC7rQ-FM',
    'Smith Machine Rows': 'https://www.youtube.com/shorts/qivPkcDI0s0',
    'Smith Machine Squats': 'https://www.youtube.com/shorts/xU4cuTffVZc',
    'Smith Machine Lunges': 'https://www.youtube.com/shorts/dFMa-mmZ6A8',
    'Smith Machine Deadlifts': 'https://www.youtube.com/shorts/Bhg9IvQzsCI'
}

# Function to print out available exercises based on user's choice
def suggest_exercises(machine: str, focus: str) -> None:
    if machine not in machine_exercises:
        print(f"Sorry, {machine} is not available for exercise suggestions.")
        return

    if focus not in machine_exercises[machine]:
        print(f"Sorry, {machine} cannot be used for {focus}.")
        return

    print(f"\nSuggested exercises using {machine} for {focus}:")
    for exercise in machine_exercises[machine][focus]:
        exercise_link = exercise_links.get(exercise, "Link not available")
        print(f"- {exercise}: {exercise_link}")

# Main function to display menu and prompt user
def main() -> None:

    machine_detected = data_cat[np.argmax(score)]
    print(f"The detected equipment is: {machine_detected}")

    print("\nWhat part of the body do you want to focus on?")
    print("1. Upper Body")
    print("2. Lower Body")
    print("3. Core")
    choice = input("Enter your choice (1/2/3): ")

    if choice == '1':
        focus = 'upper_body'
    elif choice == '2':
        focus = 'lower_body'
    elif choice == '3':
        focus = 'core'
    else:
        print("Invalid choice. Please enter a valid option (1/2/3).")
        return

    suggest_exercises(machine_detected, focus)

if __name__ == "__main__":
    main()
# Out:
# The detected equipment is: smith_machine
#
# What part of the body do you want to focus on?
# 1. Upper Body
# 2. Lower Body
# 3. Core
# Enter your choice (1/2/3): 1
#
# Suggested exercises using smith_machine for upper_body:
# - Smith Machine Bench Press: https://www.youtube.com/shorts/G-jT0m0nvx8
# - Smith Machine Shoulder Press: https://www.youtube.com/shorts/QWdaC7rQ-FM
# - Smith Machine Rows: https://www.youtube.com/shorts/qivPkcDI0s0
